# %%
import pandas as pd
from tqdm.notebook import tqdm

# %%
df = pd.read_csv('tr-tpbs.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-a6410ddb11ec> in <module>
# ----> 1 df = pd.read_csv('tr-tpbs.csv')
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: out of memory

# %%
#labels
unique_type_trtpbs = set()
for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    if pd.isnull(row['labels']):
        continue
    type_ = row['labels'].split(',')
    unique_type_trtpbs.update(type_)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=310926.0), HTML(value='')))

# %%
len(unique_type_trtpbs)
# Out:
# 49

# %%
from riko.modules import fetch, fetchsitefeed
from time import sleep

sources = [
    {'url': 'https://www.thairath.co.th/rss/news', 'name': 'ไทยรัฐ'},
    {'url': 'http://rssfeeds.sanook.com/rss/feeds/sanook/news.index.xml', 'name': 'สนุกดอทคอม'},
    {'url': 'https://news.thaipbs.or.th/rss/news', 'name': 'thaipbs'},
    {'url': 'https://www.prachachat.net/feed', 'name': 'ประชาชาติ'},
    {'url': 'http://www.lokwannee.com/web2013/?cat=69&feed=rss2', 'name': 'โลกวันนี้'},
    {'url': 'https://www.matichon.co.th/feed', 'name': 'มติชน'},
    {'url': 'https://voicetv.co.th/rss', 'name': 'Voice TV'}
]

from kafka import KafkaProducer
import json
import pykafka

def publish_message(producer, json_send_data):
    try:
        producer.produce(bytes(json.dumps(json_send_data),'ascii'))
        print('Message published successfully.')
    except Exception as ex:
        print('Exception in publishing message')
        print(str(ex))


def connect_kafka_producer():
    client = pykafka.KafkaClient("localhost:9092")
    producer = client.topics[bytes('rss-test-1','ascii')].get_producer()
    return producer

import time

whitelist_keys = ['title', 'summary', 'pubDate']

def fetch_source(source):
    stream = fetch.pipe(conf=source)
    source = source['name']
    kafka_producer = connect_kafka_producer()
    
    while(True):
        print('fetching')
        try:
            item = next(stream)
            to_json = {key: item[key] for key in whitelist_keys}
            to_json['pubDate'] = time.strftime('%Y-%m-%dT%H:%M:%SZ', item['pubDate'])
            to_json['source'] = source
            to_json['url'] = item['link']
            print(to_json['title'])
            publish_message(kafka_producer, to_json)
        except:
            sleep(5)
            pass

from multiprocessing import Pool

with Pool(5) as p:
    p.map(fetch_source, sources)
# Out:
# fetching
# fetchingfetching
#
# fetchingfetching
#
# เซ็นทรัล ฟู้ด รีเทล จัดทัพเมนูอาหารเจทั้งคาวหวาน เริ่มต้นเพียง 25 บาท
# Message published successfully.
# fetching
# เปิดมุมมอง &quot;สโคลส์&quot; หลัง &quot;คาวานี&quot; ย้ายซบ &quot;แมนยูฯ&quot; ช่วงโค้งสุดท้าย
# Message published successfully.
# fetching
# ตร.พิษณุโลก จับแอดมินเพจสวิงกิ้งคาผ้าเหลือง หนีคดีไปบวชพระอยู่พิจิตร
# อ.เจษฎ์ ไขปริศนา "ทำไมทะเลหาดบางแสน ถึงน้ำใส ตอนหน้าหนาว"Message published successfully.
#
# fetchingMessage published successfully.
# fetching
#
# ศรัทธายังอยู่ แต่รายได้หายไป วัดงัดกลยุทธ์ &quot;เก่าในใหม่&quot; สู้โควิด-19ทลายออฟฟิศ 9 เว็บพนัน ยึดทรัพย์ 75 ล้าน อึ้ง! 6 เดือน เงินหมุนเวียนกว่า 15,000 ล้าน
#
# Message published successfully.Message published successfully.
# fetching
# ผู้ปกครองถีบ "ครูจุ๋ม" โดนปรับคนละร้อย ยันผู้ปกครองส่วนใหญ่ยังไม่ยอม เอาเรื่องถึงที่สุด
# Message published successfully.
#
# fetching
# พบหนุ่มอเมริกัน ติดโควิด ครั้งที่ 2 ป่วยหนักกว่าตอนติดเชื้อหนแรกมาก
# Message published successfully.
# fetching
# วงการกีฬาร่วมน้อมรำลึกถึง ในหลวง รัชกาลที่ 9fetching
# ฮาอีกแล้ว "สายฟ้า" ถาม "พายุ" "แอบเอาครัวซองต์ไปรึเปล่า" คดีพลิก "แม่ชม" ชี้เบาะแส
# Message published successfully.
# fetching
#
# ทำเนียบคุมเข้มเฝ้าระวังม็อบบุก สันติบาลยืนยันให้ชุมนุมได้แค่สะพานชมัยมรุเชฐMessage published successfully.
# fetching
# ทิพยประกันภัย จัดกิจกรรมสานต่อโครงการในพระราชดำริ ในหลวง รัชกาลที่ 9
# Message published successfully.
#
# fetching
# ‘ปลัดสปน.’ ยัน พรุ่งนี้ ข้าราชการทำงานปกติ อัครเดช เผย มีแผนรับมือม็อบMessage published successfully.
#
# Message published successfully.
# fetching
# ทำเนียบฯ จัด จนท.ประจำจุด รอ บช.น.เจรจาม็อบใช้ ถ.นครสวรรค์ แทน &quot;ราชดำเนิน&quot;
# Message published successfully.
# fetching
# fetchingแนะวิธีเลือกรถทัวร์เช่าเหมา เตือนยึดหลัก 3 ข้อ ก่อนขับรถผ่านจุดตัดทางรถไฟ
# Message published successfully.
#
# fetching"สุเทพ" ลั่น ไปรอรับเสด็จ 14 ต.ค. "พุทธะอิสระ" ไปด้วย ชวนใส่เสื้อเหลืองแสดงพลัง
#
# เงินกฐินบนรถบัส ถึงวัดบางปลานักแล้ว เตรียมทำบุญใหญ่อุทิศให้คนตาย 19 ศพMessage published successfully.
#
# Message published successfully.fetching
#
# fetchingผบ.ตร.เตรียมพร้อมรับม็อบ 14 ต.ค. ยืนยันไม่อนุญาตให้ค้างคืน
#
# รมว.ศธ. ยัน 14 ต.ค.เปิดเรียนปกติ ชี้ ไม่เหมาะสม ปลุก นร.หยุด ร่วมม็อบMessage published successfully.
#
# fetchingMessage published successfully.
# รวบคาผ้าเหลือง! หนุ่มพิจิตร หลอกแฟนสาวเซ็กซ์สวิงกิ้ง ถ่ายคลิปขายหาเงิน14 ตุลา : การต่อสู้เชิงอุดมการณ์ เปลี่ยนโครงสร้าง และฉากจบใหม่
#
# Message published successfully.
# Message published successfully.fetching
# "ศรีสุวรรณ" จี้กระทรวงศึกษา ทำทัณฑ์บนเด็กที่ร่วมม็อบ 14 ต.ค. ห้ามรับเข้าเป็นข้าราชการ
#
# fetchingMessage published successfully.
#
# fetching
#
# fetching14 ตุลา : อดีต กปปส. ประกาศ 4 จุดนัดพบ รอรับเสด็จฯ บนถนนราชดำเนิน
# พายุฝนถล่มที่ห้วยยอด แรงลมพัดร้านกาแฟริมทางไปอยู่กลางถนน รถต้องจอดหลบ
#
# Message published successfully.พ่อเด็ก 3 ขวบ เพิ่งรู้ลูกชายเสียชีวิต ลั่น ไม่เชื่อว่าหกล้ม กระดูกหลุดเหมือนตกตึกมากกว่าMessage published successfully.
#
#
# Message published successfully.fetchingfetching
#
#
# fetching“ศักดิ์สยาม” วางพวงมาลา “สวนสุขภาพลัดโพธิ์” เนื่องในวันคล้ายวันสวรรคต ร.9ใกล้ความจริง &quot;ปาเกียว&quot; เซ็นเอเย่นต์ดัง จ่อเปิดศึก &quot;แม็คเกรเกอร์&quot;
#
#
# Message published successfully.
# Message published successfully.fetching
#
# นายกฯ เป็นประธานตักบาตรพระสงฆ์ 89 รูป เนื่องในวันคล้ายวันสวรรคตในหลวง ร.9fetching
#
# ลองของแปลก ทดสอบสิงห์เขย่งขา PEUGEOT 5008 SUV 7 ที่นั่งMessage published successfully.
# เจ้าสัว ซี.พี. รุกคืบธุรกิจการเงิน “ปล่อยกู้ดิจิทัล” รายละ 2 หมื่นบาทMessage published successfully.
#
#
# fetchingfetchingMessage published successfully.
#
# "วาดิม" ฟาดอีกระลอก ตอบคอมเมนต์แซ่บ  "ไม่เคยบอกว่าจะแต่งงานในปีนี้ "
#
# โหน่ง เล่นเลิฟซีนจน น้องเฮอริเคน ร่ำไห้ ชาวเน็ตวิจารณ์ยับละเมิดเด็กfetching
#
# Message published successfully.Message published successfully.
# ข้าวเปลือกเหนียว ดิ่งเหลือตันละ 9 พันบาท ‘พาณิชย์’ เร่งเจรจาขาย ’คอฟโก้’ จีนfetching
#
#
# วันนี้ 2 ราย! ศบค.เผยพบผู้ติดเชื้อโควิด-19 รายใหม่ เดินทางมาจากสหรัฐอเมริกา-สวีเดนMessage published successfully.fetching
#
#
# Message published successfully.fetching
# ยลโฉมเพชรสีชมพู “The Spirit of the Rose” คาดประมูลพันล้าน
#
# Message published successfully.“สุเทพ-พุทธะอิสระ” ประกาศร่วมรับเสด็จ 14 ตุลา ที่ราชดำเนินfetching
#
# fetching
# Message published successfully.เช็กชัดๆ คุณสมบัติผู้มีสิทธิ์ลงทะเบียน &quot;คนละครึ่ง&quot; ก่อนรับเงิน 3,000
#
# Message published successfully."แมงปอ ชลธิชา" เผยเส้นทางรักปิ๊งกับแดนเซอร์-วันนี้ผันตัวเป็นช่างสักปาก-คิ้ว-หัวนม
#
# fetchingMessage published successfully.
#
#
# fetchingทร. เปิดพระราชวังเดิม จัดพิธีบำเพ็ญกุศล วันคล้ายวันสวรรคต ในหลวง ร.9fetching
#
# Message published successfully.
# ตลาดหลักทรัพย์ฯ พาส่องธีมลงทุนหุ้นผันผวนต่ำ ผลตอบแทนชนะตลาด
#
# ดูแล้วยิ้มเลยกับแอคติ้ง "น้องวีจิ" สะพายกระเป๋ายืนเลือกซื้อของให้ "พ่อหนุ่ม ศรราม"Message published successfully.
# fetchingMessage published successfully.
#
# fetching
#
# &quot;พิธา&quot; ย้ำจุดยืน ยังหวัง ‘ก้าวไกล’ ปักธงประชาธิปไตยทั่วประเทศfetchingตำรวจนครบาลตั้งด่าน 21 จุด ทั่วกรุง รับมือม็อบ 14 ต.ค. เริ่มวันนี้ ยาวถึงวันศุกร์
#
# Message published successfully.
# กทม. ประสานกรมชลฯ จำกัดการระบายน้ำ “ฝั่งตะวันออก” รับมือฝนถล่มกรุง
# Message published successfully.
#
# Message published successfully.fetchingfetching
#
# ครม.ไฟเขียวถอน "กระท่อม" จากยาเสพติด แต่ห้ามขายให้เด็กอายุต่ำกว่า 18 ปี
# fetchingMessage published successfully.
#
#
# fetching
# รายการ มาสเตอร์เชฟ ไทยแลนด์ ซีซั่น 3 เข้าชิง “เอมมี่ อวอร์ดส”"ติ๊ก กนิษฐรินทร์" โพสต์ถึงลูกรัก ชีวิตแม่เหลือวีจิคนเดียว อย่าลืมแม่นะ
#
# Message published successfully.Message published successfully.
#
# fetchingfetching
#
# รัฐบาลมาเลเซียอนุมัติเงินกู้ 7.5 พันล้าน อุ้ม “แอร์เอเชีย” สู้วิกฤตโควิด
# Message published successfully."พีท ทองเจือ" โพสต์ซึ้งถึง "น้องเซย่า" ลูกสาวต้องหยุดความฝันเพราะป่วยไทรอยด์
#
# fetchingMessage published successfully.
# fetching
#
# ทำเนียบ ประกาศแผนเผชิญเหตุ ห้ามจอดรถ เตรียมรับม็อบ 14 ตุลา 63"แต้ว ณฐพร" ทำไอจีไฟลุก โพสต์ลุคสุดแซ่บทำชาวเน็ตขยี้ตารัวๆ
#
# Message published successfully.Message published successfully.
#
# fetching
# fetchingรัฐสภาสานต่อ happy workplace ปี 64 รับมือเบบีบูมเมอร์ส่งไม้ต่อคนรุ่นใหม่
# Message published successfully.
#
# fetching
# ส่องวิธีการใช้สิทธิ “คนละครึ่ง” ก่อนเริ่มลงทะเบียนจริง 16 ต.ค.นี้
# Message published successfully.
# fetching
# “SENA” ปรับโครสร้างองค์กร ส่ง “ดร.เกษรา” นั่งเอ็มดี มีผล 12 ต.ค.
# Message published successfully.
# fetching
# “วิลล่า คุณาลัย” ออกหุ้นกู้ล็อตแรก 90 ล้าน ดอกเบี้ย 6.5% ต่อปี
# Message published successfully.
# fetching
# พายุ “หลิ่นฟา” ถล่มนาข้าว 6 จังหวัด เสียหายแล้วกว่าแสนไร่
# Message published successfully.
# fetching
# “คอนติเนลทอล” มั่นใจตลาดยางรถยนต์ยังโตต่อ
# Message published successfully.
# fetching
# “โควิด” พ่นพิษ ทำคนไทย 44% รายได้ลดแถมไม่มีเงินออม 27% ต้องกู้ยืม
# Message published successfully.
# fetching
# ประยุทธ์ ตักบาตรถวายพระราชกุศล-วางพวงมาลา คล้ายวันสวรรคต ร.9
# Message published successfully.
# fetching
# สิงคโปร์-อินโดฯ ไฟเขียวนักธุรกิจข้ามประเทศ เริ่ม 26 ต.ค.นี้
# Message published successfully.
# fetching
# กทพ. เดินหน้าลงทุน 2 แสนล้าน สร้างด่วนใหม่ 9 สาย
# Message published successfully.
# fetching
# เจาะเทรนด์ “Y-Economic” แรงซื้อทรงพลังฉบับสาววาย
# Message published successfully.
# fetching
# ศบค.ผู้ติดเชื้อรายใหม่วันนี้ (13 ต.ค.) เพิ่มอีก 2 ราย
# Message published successfully.
# fetching
# เลือกตั้ง อบจ. ทั่วไทย ธ.ค. คาดเงินสะพัดกว่าหมื่นล้าน
# Message published successfully.
# fetching
# บทวิเคราะห์ ราคาทองคำวันนี้ (13 ต.ค. 2563) โดย YLG Bullion
# Message published successfully.
# fetching
# เม.ย.64 เริ่มสร้างไฮสปีด บิ๊กซี.พี. มั่นใจเปิดให้บริการได้ 2559
# Message published successfully.
# fetching
# ราคาทองวันนี้ (13 ต.ค.) ปรับลง 50 บาท ทองรูปพรรณบาทละ 28,800 บาท
# Message published successfully.
# fetching
# หวัง อี้ เยือนไทย พบ ประยุทธ์ 14-15 ต.ค. ขรก.ทำเนียบ พร้อม WFH หนีม็อบคณะราษฎร
# Message published successfully.
# fetching
# เอไอเอสชวนชาวออฟฟิศอัปสวัสดิการให้เต็มแม็กซ์ กับ “Health Easy” ตัวช่วยดี๊ดีที่ต้องมีในยุคนี้
# Message published successfully.
# fetching
# อุตุฯ เตือน 14-15 ต.ค. อีสานมีฝนเพิ่ม อิทธิพล พายุ “นังกา”
# Message published successfully.
# fetching
# “ออร่ามี” ดีง ภณ ณวัสน์ และชิปปี้ ศิรินทร์ เสริมทัพพรีเซนเตอร์ พร้อมเปิดตัวผลิตภัณฑ์ใหม่
# Message published successfully.
# fetching
# ม.มหิดล วิจัยกระตุ้นสมองด้วยไฟฟ้ากระแสตรงผ่านกะโหลกศีรษะผู้ป่วยโรคหลอดเลือดสมอง ช่วยฟื้นฟูการเคลื่อนไหวดีขึ้น
# Message published successfully.
# fetching
# ผู้เชี่ยวชาญเผย เคล็ดลับชะลอวัยสุขภาพดีและอายุยืน พร้อมเปิดหลักสูตรชะลอวัยฯ แบบเข้มข้น 4 วัน นำไปปฏิบัติได้จริง
# Message published successfully.
# fetching
# โรงแรมเคป พันวา ภูเก็ต  ให้การต้อนรับ “ดร.ก้องศักด ยอดมณี” ผู้ว่าการ การกีฬาแห่งประเทศไทย
# Message published successfully.
# fetching
# สุขกายสุขใจพร้อมอิ่มบุญตลอดเทศกาลกินเจ  ณ ห้องอาหารแทพเพสทรี โรงแรมคลาสสิค คามิโอ ระยอง
# Message published successfully.
# fetching
# CP FreshMart ฉลองเปิดสาขาใหม่ ‘คู้บอน 39′ เสิร์ฟอาหารคุณภาพ พร้อมบริการส่งถึงบ้านฟรี รับวิถี New Normal
# Message published successfully.
# fetching
# KK เริ่มซื้อขายในตลาดหลักทรัพย์ เอ็ม เอ ไอ วันแรก
# Message published successfully.
# fetching
# วิริยะประกันภัย ร่วมสนับสนุน “โครงการ คปภ. เพื่อคนพิการ” ประจำปี 2563
# Message published successfully.
# fetching
# คอร์สฟรี SET e-Learning ห้องเรียนผู้ประกอบการ 7 หลักสูตรใหม่
# Message published successfully.
# fetching
# สมาคมนิสิตเก่าจุฬาฯ พร้อมจัดงาน “ปิยมหาราชานุสรณ์ 2563” ยิ่งใหญ่ตลอดเดือน ต.ค.
# Message published successfully.
# fetching
# ไทยประกันชีวิตส่งแบบประกัน “ทรัพย์บำนาญ G 85” ส่งท้ายปี
# Message published successfully.
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetching
# fetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetchingfetchingfetching
#
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# fetching
# fetchingfetching
#
# fetching
# fetching
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-6:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-10:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-2-fd3283ed043e>", line 44, in fetch_source
#     item = next(stream)
#   File "<ipython-input-2-fd3283ed043e>", line 44, in fetch_source
#     item = next(stream)
# Traceback (most recent call last):
#   File "<ipython-input-2-fd3283ed043e>", line 44, in fetch_source
#     item = next(stream)
#   File "<ipython-input-2-fd3283ed043e>", line 44, in fetch_source
#     item = next(stream)
# StopIteration
# StopIteration
# StopIteration
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# StopIteration
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#
# During handling of the above exception, another exception occurred:
#
#   File "<ipython-input-2-fd3283ed043e>", line 44, in fetch_source
#     item = next(stream)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# StopIteration
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-fd3283ed043e>", line 54, in fetch_source
#     sleep(5)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "<ipython-input-2-fd3283ed043e>", line 54, in fetch_source
#     sleep(5)
#   File "<ipython-input-2-fd3283ed043e>", line 54, in fetch_source
#     sleep(5)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-2-fd3283ed043e>", line 54, in fetch_source
#     sleep(5)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-2-fd3283ed043e>", line 54, in fetch_source
#     sleep(5)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fd3283ed043e> in <module>
#      58
#      59 with Pool(5) as p:
# ---> 60     p.map(fetch_source, sources)
#
# /usr/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
